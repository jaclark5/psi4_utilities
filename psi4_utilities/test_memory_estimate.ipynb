# %%
import psi4 

qce_mol = psi4.core.Molecule.from_string("""
0 1
H  0.0  0.0  0.0
H  0.0  0.0  0.74
""")

# %%
from psi4_utilities import psi4_utilities

psi4_utilities.find_aux_sets("aug-cc-pVTZ")
# Out:
# ['2ZaP', '2ZaPa-NR', '2ZaPa-NR-CV', '3-21G', '3ZaP', '3ZaPa-NR', '3ZaPa-NR-CV', '4-31G', '4ZaP', '4ZaPa-NR', '4ZaPa-NR-CV', '5-21G', '5ZaP', '5ZaPa-NR', '5ZaPa-NR-CV', '6-21G', '6-31++G', '6-31++G*', '6-31++G**', '6-31++G**-J', '6-31+G', '6-31+G*', '6-31+G**', '6-31+G*-J', '6-311++G', '6-311++G(2d,2p)', '6-311++G(3df,3pd)', '6-311++G*', '6-311++G**', '6-311++G**-J', '6-311+G', '6-311+G(2d,p)', '6-311+G*', '6-311+G**', '6-311+G*-J', '6-311G', '6-311G(2df,2pd)', '6-311G(d,p)', '6-311G*', '6-311G**', '6-311G**-RIFIT', '6-311G-J', '6-311xxG(d,p)', '6-31G', '6-31G(2df,p)', '6-31G(3df,3pd)', '6-31G(d,p)', '6-31G*', '6-31G**', '6-31G**-RIFIT', '6-31G*-Blaudeau', '6-31G-Blaudeau', '6-31G-J', '6ZaP', '6ZaPa-NR', '7ZaPa-NR', 'AHGBS-5', 'AHGBS-7', 'AHGBS-9', 'AHGBSP1-5', 'AHGBSP1-7', 'AHGBSP1-9', 'AHGBSP2-5', 'AHGBSP2-7', 'AHGBSP2-9', 'AHGBSP3-5', 'AHGBSP3-7', 'AHGBSP3-9', 'ANO-DK3', 'ANO-R', 'ANO-R0', 'ANO-R1', 'ANO-R2', 'ANO-R3', 'ANO-RCC', 'ANO-RCC-MB', 'ANO-RCC-VDZ', 'ANO-RCC-VDZP', 'ANO-RC
# ...

# %%
psi4_mol = psi4.geometry(qce_mol.to_string(dtype='psi4'))
# Set options only if values are not None
options = {
    key: value for key, value in {
        'basis': "aug-cc-pVTZ-dk",
        'print': 5
    }.items() if value is not None
}
psi4.set_options(options)

# %%
plan = psi4.energy('wB97X-3c', )# return_wfn=True)
# Out:
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on Mac
# *** at Thu May  1 16:53:58 2025
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVTZ-DK
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry H          line    18 file /Users/jenniferclark/.local/share/mamba/envs/p4env/share/psi4/basis/aug-cc-pvtz-dk.gbs
#
#    => WB97X3C: psi4_utilitiesirical Dispersion <=
#
#     Grimme's -D4 (BJ-damping) Dispersion Correction with ATM
#     Caldeweyher, E.; Ehlert, S.; Hansen, A.; Neugebauer, H.; Spicher, S.; Bannwarth, C.; Grimmme, S., J. Chem. Phys. 150, 154122 (2019)
#
#         a1 =       0.246400
#         a2 =       4.737000
#        alp =      16.000000
#         s6 =       1.000000
#         s8 =       0.000000
#         s9 =       1.000000
#
#
# ...

# %%
dir(plan)
# Out:
# ['Config',
#  '__abstractmethods__',
#  '__annotations__',
#  '__base_doc__',
#  '__class__',
#  '__class_vars__',
#  '__config__',
#  '__custom_root_type__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__exclude_fields__',
#  '__fields__',
#  '__fields_set__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__get_validators__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__include_fields__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__json_encoder__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__post_root_validators__',
#  '__pre_root_validators__',
#  '__pretty__',
#  '__private_attributes__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__repr_args__',
#  '__repr_name__',
#  '__repr_str__',
#  '__rich_repr__',
#  '__schema_cache__',
#  '__setattr__',
#  '__setstate__',
#  '__signature__',
#  '__sizeof__',
#  '__slots__',
#  '__static_attributes__',
# ...

# %%
plan.__dict__
# Out:
# {'molecule': <psi4.core.Molecule at 0x126a745f0>,
#  'basis': 'aug-cc-pvtz-dk',
#  'method': 'wb97x-3c',
#  'driver': <DriverEnum.energy: 'energy'>,
#  'keywords': {'PRINT': 5, 'function_kwargs': {}},
#  'protocols': {'stdout': True},
#  'tag': '*',
#  'priority': 1,
#  'owner_group': None,
#  'computed': False,
#  'result': {},
#  'result_id': None,
#  'return_plan': True}
